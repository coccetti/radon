# %% [markdown]
# # Unsupervised GMM clustering — welded CR-39 tracks
#
# Same pipeline as [`gmm_nn_unsup_4.py`](gmm_nn_unsup_4.py): ROI threshold → morphological closing (welding) → contour features → GMM.
#
# This notebook adds **full per-cluster statistics** and **evaluation plots** (montages, t-SNE, silhouette, spatial overlays) modelled on Step 3 of `algorithms/radon_track_nn.ipynb`.

# %% [markdown]
# ## Step 0 — Setup, configuration and image I/O

# %%
import sys
from pathlib import Path

import cv2
import joblib
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.patches import Patch
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

GMM_DIR = Path.cwd() if (Path.cwd() / "gmm_nn_unsup_4.py").exists() else Path.cwd() / "gmm"
if str(GMM_DIR) not in sys.path:
    sys.path.insert(0, str(GMM_DIR))

from gmm_nn_unsup_4 import (
    Config,
    extract_features_from_roi,
    cluster_colors_rgb,
    cluster_norm,
    contour_centroid,
    contour_max_intensity,
    meta_row_from_contour,
    apply_watershed_pass,
    compare_watershed_methods,
    suggest_artifact_clusters,
    resolve_ws_clusters,
    load_macro_counts,
    build_count_comparison,
    save_count_comparison_plots,
    plot_roi_three_variants,
    roi_window_counts,
    discover_images,
    summarize_cref_inventory,
    image_display_name,
    resolve_visual_roi_image,
)

cfg = Config()
cfg.output_dir.mkdir(parents=True, exist_ok=True)

# --- CREF file selection (None = all) ---
cfg.filter_lab = None              # e.g. "P2-DOT"
cfg.filter_period = None           # 1, 2, or 3
cfg.filter_position_group = None   # "A", "B", or "C"

PATCH_SIZE = 48 # 48 pixels
MONTAGE_N = 24
MONTAGE_COLS = 8
ROI_WINDOW = 700
# Fixed ROI for cross-run comparison (5.6b); None => first selected image
COMPARE_ROI_IMAGE = None
COMPARE_ROI_X0 = 200
COMPARE_ROI_Y0 = 400
FOCUS_CLUSTER = 1  # single-cluster spatial plot after fig2
FOCUS_CMAP = "turbo"  # continuous colormap; scales to large event counts
CLUSTER_CMAP = "turbo"  # continuous colormap for cluster id 0..K-1

# Step 6 — watershed + artifact tagging
WS_MIN_AREA = 160
WS_MIN_FRAGMENT_AREA = 20
WS_CLUSTER_FILTER = False
WATERSHED_CLUSTERS = None  # empty => auto from mean area >= WS_MIN_AREA 
WS_METHOD = "distance_peaks"
ARTIFACT_CLUSTERS = None  # None => saliency heuristic; or e.g. [0, 4, 5]

# Visual comparison ROI (usual field of view); None => first selected image
VISUAL_COMPARE_ROI_IMAGE = None
VISUAL_COMPARE_ROI_X0 = 700
VISUAL_COMPARE_ROI_Y0 = 1400
VISUAL_COMPARE_ROI_SIZE = 700

np.random.seed(cfg.random_state)

inventory = summarize_cref_inventory(cfg.data_dir)
print(f"data_dir: {cfg.data_dir}")
print(f"output_dir: {cfg.output_dir}")
print(f"CREF inventory: {inventory['total_files']} files")
print(f"  labs: {inventory['labs']}")
print(f"  periods: {inventory['periods']}")
print(f"  position groups: {inventory['position_groups']}")

image_paths = discover_images(cfg)
print(
    f"selected {len(image_paths)} image(s)"
    f" (lab={cfg.filter_lab}, period={cfg.filter_period}, position={cfg.filter_position_group})"
)
if image_paths:
    print("  first:", image_paths[0].name)
    if COMPARE_ROI_IMAGE is None:
        COMPARE_ROI_IMAGE = image_paths[0].name
    if VISUAL_COMPARE_ROI_IMAGE is None:
        VISUAL_COMPARE_ROI_IMAGE = resolve_visual_roi_image(cfg, [p.name for p in image_paths])
# Out:
# data_dir: /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/data_cref/data
# output_dir: /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/cref/outputs
# CREF inventory: 225 files
#   labs: ['P2-DOT', 'PS-LAB', 'PS-RIS', 'PT-MUS', 'PT-RIS']
#   periods: ['T1', 'T2', 'T3']
#   position groups: ['A', 'B', 'C']
# selected 225 image(s) (lab=None, period=None, position=None)
#   first: CREF_P2-DOT_T1_A1_LBS255518.jpg

# %% [markdown]
# ## Step 1 — Feature extraction (welded contours + event registry)

# %%
if not image_paths:
    raise FileNotFoundError(f"No files matching {cfg.image_glob} in {cfg.data_dir}")

print("Extracting physical features with spatial coalescence (welding)...")
all_features = []
meta_rows = []
image_registry = []
label_offset = 0

for path in image_paths:
    print(f"  Scanning {path.name}...")
    feats, cnts, roi, debug_thresh = extract_features_from_roi(path, cfg)
    if feats is None:
        continue
    print(f"    -> Extracted {len(feats)} valid events (Area >= {cfg.min_area}px).")
    if cfg.save_debug_images and debug_thresh is not None:
        cv2.imwrite(str(cfg.output_dir / f"debug_binary_{path.stem}.png"), debug_thresh)
    if len(feats) == 0:
        continue
    for i, cnt in enumerate(cnts):
        meta_rows.append(meta_row_from_contour(path.name, roi, cnt))
    all_features.append(feats)
    image_registry.append({
        "path": path,
        "counts": len(feats),
        "label_start": label_offset,
        "contours": cnts,
        "roi": roi,
    })
    label_offset += len(feats)

if not all_features:
    raise RuntimeError("CRITICAL ZERO COUNT: The signal is completely empty.")

X = np.vstack(all_features)
meta = pd.DataFrame(meta_rows)
assert len(meta) == len(X)
print(f"\nTotal physical events across {len(image_registry)} images: {len(X)}")
# Out:
# Extracting physical features with spatial coalescence (welding)...
#   Scanning CREF_P2-DOT_T1_A1_LBS255518.jpg...
#     -> Extracted 1162 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_A2_LBS255509.jpg...
#     -> Extracted 1154 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_A3_LBS255512.jpg...
#     -> Extracted 1112 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_A4_LBS255506.jpg...
#     -> Extracted 1132 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_A5_LBS255517.jpg...
#     -> Extracted 974 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_B1_LBS255508.jpg...
#     -> Extracted 1034 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_B2_LBS255505.jpg...
#     -> Extracted 715 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_B3_LBS255507.jpg...
#     -> Extracted 931 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_B4_LBS255514.jpg...
#     -> Extracted 1008 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_B5_LBS255516.jpg...
#     -> Extracted 921 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_C1_LBS255511.jpg...
#     -> Extracted 953 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_C2_LBS255513.jpg...
#     -> Extracted 934 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_C3_LBS255515.jpg...
#     -> Extracted 1068 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_C4_LBS255510.jpg...
#     -> Extracted 935 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T1_C5_LBS255519.jpg...
#     -> Extracted 962 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_A1_LBS259544.jpg...
#     -> Extracted 1741 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_A2_LBS259541.jpg...
#     -> Extracted 1919 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_A3_LBS259535.jpg...
#     -> Extracted 1560 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_A4_LBS259539.jpg...
#     -> Extracted 1861 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_A5_LBS259533.jpg...
#     -> Extracted 1738 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_B1_LBS259537.jpg...
#     -> Extracted 1313 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_B2_LBS259538.jpg...
#     -> Extracted 1382 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_B3_LBS259547.jpg...
#     -> Extracted 1661 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_B4_LBS259542.jpg...
#     -> Extracted 1564 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_B5_LBS259540.jpg...
#     -> Extracted 1589 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_C1_LBS259545.jpg...
#     -> Extracted 1684 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_C2_LBS259546.jpg...
#     -> Extracted 1619 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_C3_LBS259536.jpg...
#     -> Extracted 1545 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_C4_LBS259534.jpg...
#     -> Extracted 1551 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T2_C5_LBS259543.jpg...
#     -> Extracted 1744 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_A1_LBS263594.jpg...
#     -> Extracted 689 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_A2_LBS263595.jpg...
#     -> Extracted 834 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_A3_LBS263596.jpg...
#     -> Extracted 766 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_A4_LBS263597.jpg...
#     -> Extracted 894 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_A5_LBS263598.jpg...
#     -> Extracted 770 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_B1_LBS263599.jpg...
#     -> Extracted 685 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_B2_LBS263600.jpg...
#     -> Extracted 740 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_B3_LBS263601.jpg...
#     -> Extracted 781 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_B4_LBS263602.jpg...
#     -> Extracted 690 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_B5_LBS263603.jpg...
#     -> Extracted 547 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_C1_LBS263604.jpg...
#     -> Extracted 1856 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_C2_LBS263605.jpg...
#     -> Extracted 724 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_C3_LBS263606.jpg...
#     -> Extracted 597 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_C4_LBS263607.jpg...
#     -> Extracted 787 valid events (Area >= 20.0px).
#   Scanning CREF_P2-DOT_T3_C5_LBS263608.jpg...
#     -> Extracted 727 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_A1_LBS255611.jpg...
#     -> Extracted 942 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_A2_LBS255612.jpg...
#     -> Extracted 859 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_A3_LBS255619.jpg...
#     -> Extracted 863 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_A4_LBS255622.jpg...
#     -> Extracted 978 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_A5_LBS255614.jpg...
#     -> Extracted 819 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_B1_LBS255623.jpg...
#     -> Extracted 873 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_B2_LBS255618.jpg...
#     -> Extracted 767 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_B3_LBS255624.jpg...
#     -> Extracted 959 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_B4_LBS255617.jpg...
#     -> Extracted 935 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_B5_LBS255625.jpg...
#     -> Extracted 905 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_C1_LBS255616.jpg...
#     -> Extracted 719 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_C2_LBS255621.jpg...
#     -> Extracted 882 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_C3_LBS255620.jpg...
#     -> Extracted 932 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_C4_LBS255613.jpg...
#     -> Extracted 842 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T1_C5_LBS255615.jpg...
#     -> Extracted 828 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_A1_LBS259524.jpg...
#     -> Extracted 1467 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_A2_LBS259526.jpg...
#     -> Extracted 1378 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_A3_LBS259529.jpg...
#     -> Extracted 1272 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_A4_LBS259528.jpg...
#     -> Extracted 1406 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_A5_LBS259530.jpg...
#     -> Extracted 892 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_B1_LBS259527.jpg...
#     -> Extracted 944 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_B2_LBS259520.jpg...
#     -> Extracted 1340 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_B3_LBS259518.jpg...
#     -> Extracted 1298 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_B4_LBS259519.jpg...
#     -> Extracted 1334 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_B5_LBS259531.jpg...
#     -> Extracted 1418 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_C1_LBS259532.jpg...
#     -> Extracted 1388 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_C2_LBS259525.jpg...
#     -> Extracted 1304 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_C3_LBS259522.jpg...
#     -> Extracted 1237 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_C4_LBS259521.jpg...
#     -> Extracted 1420 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T2_C5_LBS259523.jpg...
#     -> Extracted 1606 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_A1_LBS263624.jpg...
#     -> Extracted 685 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_A2_LBS263625.jpg...
#     -> Extracted 741 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_A3_LBS263626.jpg...
#     -> Extracted 615 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_A4_LBS263627.jpg...
#     -> Extracted 785 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_A5_LBS263628.jpg...
#     -> Extracted 542 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_B1_LBS263629.jpg...
#     -> Extracted 678 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_B2_LBS263630.jpg...
#     -> Extracted 541 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_B3_LBS263631.jpg...
#     -> Extracted 748 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_B4_LBS263632.jpg...
#     -> Extracted 570 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_B5_LBS263633.jpg...
#     -> Extracted 716 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_C1_LBS263634.jpg...
#     -> Extracted 583 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_C2_LBS263635.jpg...
#     -> Extracted 624 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_C3_LBS263636.jpg...
#     -> Extracted 699 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_C4_LBS263637.jpg...
#     -> Extracted 616 valid events (Area >= 20.0px).
#   Scanning CREF_PS-LAB_T3_C5_LBS263638.jpg...
#     -> Extracted 564 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_A1_LBS255558.jpg...
#     -> Extracted 467 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_A2_LBS255557.jpg...
#     -> Extracted 308 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_A3_LBS255562.jpg...
#     -> Extracted 478 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_A4_LBS255553.jpg...
#     -> Extracted 304 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_A5_LBS255555.jpg...
#     -> Extracted 312 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_B1_LBS255559.jpg...
#     -> Extracted 409 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_B2_LBS255554.jpg...
#     -> Extracted 258 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_B3_LBS255550.jpg...
#     -> Extracted 373 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_B4_LBS255560.jpg...
#     -> Extracted 416 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_B5_LBS255552.jpg...
#     -> Extracted 285 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_C1_LBS255563.jpg...
#     -> Extracted 408 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_C2_LBS255551.jpg...
#     -> Extracted 373 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_C3_LBS255561.jpg...
#     -> Extracted 435 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_C4_LBS255564.jpg...
#     -> Extracted 403 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T1_C5_LBS255556.jpg...
#     -> Extracted 311 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_A1_LBS259592.jpg...
#     -> Extracted 775 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_A2_LBS259588.jpg...
#     -> Extracted 859 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_A3_LBS259578.jpg...
#     -> Extracted 709 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_A4_LBS259590.jpg...
#     -> Extracted 1055 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_A5_LBS259591.jpg...
#     -> Extracted 882 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_B1_LBS259586.jpg...
#     -> Extracted 640 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_B2_LBS259584.jpg...
#     -> Extracted 741 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_B3_LBS259581.jpg...
#     -> Extracted 557 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_B4_LBS259580.jpg...
#     -> Extracted 709 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_B5_LBS259579.jpg...
#     -> Extracted 692 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_C1_LBS259582.jpg...
#     -> Extracted 544 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_C2_LBS259585.jpg...
#     -> Extracted 739 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_C3_LBS259583.jpg...
#     -> Extracted 795 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_C4_LBS259587.jpg...
#     -> Extracted 658 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T2_C5_LBS259589.jpg...
#     -> Extracted 678 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_A1_LBS263564.jpg...
#     -> Extracted 533 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_A2_LBS263565.jpg...
#     -> Extracted 559 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_A3_LBS263566.jpg...
#     -> Extracted 411 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_A4_LBS263567.jpg...
#     -> Extracted 435 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_A5_LBS263568.jpg...
#     -> Extracted 470 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_B1_LBS263569.jpg...
#     -> Extracted 427 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_B2_LBS263570.jpg...
#     -> Extracted 591 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_B3_LBS263571.jpg...
#     -> Extracted 384 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_B4_LBS263572.jpg...
#     -> Extracted 385 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_B5_LBS263573.jpg...
#     -> Extracted 397 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_C1_LBS263574.jpg...
#     -> Extracted 610 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_C2_LBS263575.jpg...
#     -> Extracted 581 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_C3_LBS263576.jpg...
#     -> Extracted 473 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_C4_LBS263577.jpg...
#     -> Extracted 477 valid events (Area >= 20.0px).
#   Scanning CREF_PS-RIS_T3_C5_LBS263578.jpg...
#     -> Extracted 546 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_A1_LBS255535.jpg...
#     -> Extracted 692 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_A2_LBS255544.jpg...
#     -> Extracted 740 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_A3_LBS255542.jpg...
#     -> Extracted 761 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_A4_LBS255537.jpg...
#     -> Extracted 624 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_A5_LBS255543.jpg...
#     -> Extracted 706 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_B1_LBS255541.jpg...
#     -> Extracted 566 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_B2_LBS255536.jpg...
#     -> Extracted 510 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_B3_LBS255546.jpg...
#     -> Extracted 574 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_B4_LBS255538.jpg...
#     -> Extracted 695 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_B5_LBS255547.jpg...
#     -> Extracted 540 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_C1_LBS255539.jpg...
#     -> Extracted 580 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_C2_LBS255549.jpg...
#     -> Extracted 530 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_C3_LBS255540.jpg...
#     -> Extracted 650 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_C4_LBS255548.jpg...
#     -> Extracted 593 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T1_C5_LBS255545.jpg...
#     -> Extracted 529 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_A1_LBS259554.jpg...
#     -> Extracted 1226 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_A2_LBS259549.jpg...
#     -> Extracted 1301 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_A3_LBS259548.jpg...
#     -> Extracted 1235 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_A4_LBS259560.jpg...
#     -> Extracted 1205 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_A5_LBS259556.jpg...
#     -> Extracted 1365 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_B1_LBS259552.jpg...
#     -> Extracted 1226 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_B2_LBS259558.jpg...
#     -> Extracted 806 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_B3_LBS259550.jpg...
#     -> Extracted 1033 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_B4_LBS259555.jpg...
#     -> Extracted 1073 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_B5_LBS259561.jpg...
#     -> Extracted 1051 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_C1_LBS259559.jpg...
#     -> Extracted 1002 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_C2_LBS259562.jpg...
#     -> Extracted 1164 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_C3_LBS259553.jpg...
#     -> Extracted 1187 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_C4_LBS259557.jpg...
#     -> Extracted 1289 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T2_C5_LBS259551.jpg...
#     -> Extracted 1196 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_A1_LBS263579.jpg...
#     -> Extracted 1348 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_A2_LBS263580.jpg...
#     -> Extracted 931 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_A3_LBS263581.jpg...
#     -> Extracted 1122 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_A4_LBS263582.jpg...
#     -> Extracted 1218 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_A5_LBS263583.jpg...
#     -> Extracted 1344 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_B1_LBS263584.jpg...
#     -> Extracted 845 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_B2_LBS263585.jpg...
#     -> Extracted 823 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_B3_LBS263586.jpg...
#     -> Extracted 922 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_B4_LBS263587.jpg...
#     -> Extracted 776 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_B5_LBS263588.jpg...
#     -> Extracted 802 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_C1_LBS263589.jpg...
#     -> Extracted 933 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_C2_LBS263590.jpg...
#     -> Extracted 714 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_C3_LBS263591.jpg...
#     -> Extracted 800 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_C4_LBS263592.jpg...
#     -> Extracted 972 valid events (Area >= 20.0px).
#   Scanning CREF_PT-MUS_T3_C5_LBS263593.jpg...
#     -> Extracted 737 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_A1_LBS255587.jpg...
#     -> Extracted 459 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_A2_LBS255586.jpg...
#     -> Extracted 437 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_A3_LBS255590.jpg...
#     -> Extracted 438 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_A4_LBS255588.jpg...
#     -> Extracted 485 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_A5_LBS255591.jpg...
#     -> Extracted 384 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_B1_LBS255593.jpg...
#     -> Extracted 407 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_B2_LBS255594.jpg...
#     -> Extracted 475 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_B3_LBS255582.jpg...
#     -> Extracted 495 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_B4_LBS255589.jpg...
#     -> Extracted 500 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_B5_LBS255583.jpg...
#     -> Extracted 406 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_C1_LBS255585.jpg...
#     -> Extracted 423 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_C2_LBS255584.jpg...
#     -> Extracted 369 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_C3_LBS255595.jpg...
#     -> Extracted 419 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_C4_LBS255580.jpg...
#     -> Extracted 449 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T1_C5_LBS255581.jpg...
#     -> Extracted 415 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_A1_LBS259573.jpg...
#     -> Extracted 500 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_A2_LBS259563.jpg...
#     -> Extracted 580 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_A3_LBS259564.jpg...
#     -> Extracted 751 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_A4_LBS259569.jpg...
#     -> Extracted 748 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_A5_LBS259567.jpg...
#     -> Extracted 541 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_B1_LBS259572.jpg...
#     -> Extracted 671 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_B2_LBS259570.jpg...
#     -> Extracted 534 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_B3_LBS259575.jpg...
#     -> Extracted 715 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_B4_LBS259568.jpg...
#     -> Extracted 562 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_B5_LBS259566.jpg...
#     -> Extracted 851 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_C1_LBS259571.jpg...
#     -> Extracted 802 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_C2_LBS259565.jpg...
#     -> Extracted 594 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_C3_LBS259574.jpg...
#     -> Extracted 767 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_C4_LBS259576.jpg...
#     -> Extracted 492 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T2_C5_LBS259577.jpg...
#     -> Extracted 554 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_A1_LBS263549.jpg...
#     -> Extracted 522 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_A2_LBS263550.jpg...
#     -> Extracted 471 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_A3_LBS263551.jpg...
#     -> Extracted 480 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_A4_LBS263552.jpg...
#     -> Extracted 633 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_A5_LBS263553.jpg...
#     -> Extracted 571 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_B1_LBS263554.jpg...
#     -> Extracted 617 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_B2_LBS263555.jpg...
#     -> Extracted 662 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_B3_LBS263556.jpg...
#     -> Extracted 569 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_B4_LBS263557.jpg...
#     -> Extracted 545 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_B5_LBS263558.jpg...
#     -> Extracted 805 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_C1_LBS263559.jpg...
#     -> Extracted 491 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_C2_LBS263560.jpg...
#     -> Extracted 498 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_C3_LBS263561.jpg...
#     -> Extracted 506 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_C4_LBS263562.jpg...
#     -> Extracted 524 valid events (Area >= 20.0px).
#   Scanning CREF_PT-RIS_T3_C5_LBS263563.jpg...
#     -> Extracted 615 valid events (Area >= 20.0px).
#
# Total physical events across 225 images: 183587

# %% [markdown]
# ## Step 2 — GMM fit and script-parity exports

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(f"Fitting Gaussian Mixture Model with k={cfg.n_clusters} classes...")
gmm = GaussianMixture(
    n_components=cfg.n_clusters,
    covariance_type="full",
    random_state=cfg.random_state,
)
gmm.fit(X_scaled)
labels = gmm.predict(X_scaled)
posterior = gmm.predict_proba(X_scaled)

meta = meta.copy()
meta["cluster"] = labels
meta["posterior"] = posterior[np.arange(len(labels)), labels]
meta_gmm = meta.copy()
K = cfg.n_clusters

print("\ncluster sizes:")
print(meta["cluster"].value_counts().sort_index())

# Cluster colours: continuous colormap sampled at ids 0..K-1
colors_rgb = cluster_colors_rgb(K, CLUSTER_CMAP)
colors_bgr = [
    (int(b * 255), int(g * 255), int(r * 255)) for r, g, b in colors_rgb
]
_cluster_cmap = plt.colormaps[CLUSTER_CMAP]
_cluster_norm = cluster_norm(K)

# Fig 1: feature space (area vs circularity)
plt.figure(figsize=(10, 8))
scatter = plt.scatter(
    X[:, 0],
    X[:, 2],
    c=labels,
    cmap=_cluster_cmap,
    norm=_cluster_norm,
    alpha=0.65,
    s=8,
)
plt.xlabel("Track Area (pixels)")
plt.ylabel(r"Circularity Index ($4\pi A / P^2$)")
plt.title("GMM Clustering of Welded CR-39 Alpha Tracks")
plt.colorbar(scatter, label="GMM Cluster", ticks=list(range(K)))
plt.grid(True, alpha=0.3)
plt.savefig(cfg.output_dir / "fig1_feature_space.pdf", bbox_inches="tight")
plt.show()

# Minimal cluster profiles (script parity)
profile_rows = []
for cluster_id in range(K):
    mask = labels == cluster_id
    cluster_feats = X[mask]
    if len(cluster_feats) > 0:
        profile_rows.append({
            "cluster_id": cluster_id,
            "event_count": len(cluster_feats),
            "mean_area_px": float(np.mean(cluster_feats[:, 0])),
            "mean_circularity": float(np.mean(cluster_feats[:, 2])),
            "mean_aspect_ratio": float(np.mean(cluster_feats[:, 3])),
        })
pd.DataFrame(profile_rows).to_csv(cfg.output_dir / "gmm_cluster_profiles.csv", index=False)

# Fig 2: spatial mapping on first image (same cluster colours as fig1)
if image_registry:
    sample = image_registry[0]
    start = sample["label_start"]
    end = start + sample["counts"]
    sample_labels = labels[start:end]
    roi_norm = cv2.normalize(sample["roi"], None, 0, 255, cv2.NORM_MINMAX)
    roi_color = cv2.cvtColor(roi_norm, cv2.COLOR_GRAY2BGR)
    for idx, cnt in enumerate(sample["contours"]):
        c_id = sample_labels[idx]
        cv2.drawContours(roi_color, [cnt], -1, colors_bgr[c_id], 1)
    plt.figure(figsize=(12, 12), dpi=150)
    plt.imshow(cv2.cvtColor(roi_color, cv2.COLOR_BGR2RGB))
    plt.title(f"Segmented Morphology - {sample['path'].name}")
    plt.axis("off")
    legend_handles = [
        Patch(
            facecolor=colors_rgb[c],
            edgecolor="white",
            label=f"cluster {c} (n={int((sample_labels == c).sum())})",
        )
        for c in range(K)
    ]
    plt.legend(handles=legend_handles, loc="upper right", fontsize=9, framealpha=0.85)
    plt.savefig(cfg.output_dir / "fig2_spatial_mapping.png", bbox_inches="tight")
    plt.show()

    # Fig 2b: one cluster only — each event gets a distinct colormap colour
    focus_idx = np.where(sample_labels == FOCUS_CLUSTER)[0]
    n_focus = len(focus_idx)
    if n_focus == 0:
        print(f"No cluster-{FOCUS_CLUSTER} events on {sample['path'].name}; skip focus plot.")
    else:
        roi_focus = cv2.cvtColor(roi_norm, cv2.COLOR_GRAY2BGR)
        cmap = plt.get_cmap(FOCUS_CMAP)
        for rank, idx in enumerate(focus_idx):
            t = rank / max(n_focus - 1, 1)
            r, g, b, _ = cmap(t)
            bgr = (int(b * 255), int(g * 255), int(r * 255))
            cv2.drawContours(roi_focus, [sample["contours"][idx]], -1, bgr, 1)
        fig, ax = plt.subplots(figsize=(12, 12), dpi=150)
        ax.imshow(cv2.cvtColor(roi_focus, cv2.COLOR_BGR2RGB))
        ax.set_title(
            f"Cluster {FOCUS_CLUSTER} only — {n_focus} events  ({sample['path'].name})\n"
            f"each contour coloured by {FOCUS_CMAP} (event index within cluster)",
            fontsize=11,
        )
        ax.axis("off")
        sm = plt.cm.ScalarMappable(
            cmap=cmap,
            norm=plt.Normalize(vmin=0, vmax=max(n_focus - 1, 1)),
        )
        sm.set_array([])
        cbar = fig.colorbar(sm, ax=ax, fraction=0.035, pad=0.02)
        cbar.set_label(f"event index (0 … {n_focus - 1})")
        focus_path = cfg.output_dir / f"fig2_spatial_mapping_cluster{FOCUS_CLUSTER}.png"
        fig.savefig(focus_path, bbox_inches="tight")
        plt.show()
        print(f"Saved {focus_path}  ({n_focus} events)")

joblib.dump({"scaler": scaler, "gmm": gmm}, cfg.output_dir / "gmm_model.joblib")
print(f"Saved gmm_model.joblib, fig1, fig2, gmm_cluster_profiles.csv → {cfg.output_dir}")
# Out:
# Fitting Gaussian Mixture Model with k=4 classes...
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# cluster sizes:
# cluster
# 0    38548
# 1    83449
# 2    48983
# 3    12607
# Name: count, dtype: int64
# Saved /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/cref/outputs/fig2_spatial_mapping_cluster1.png  (392 events)
# Saved gmm_model.joblib, fig1, fig2, gmm_cluster_profiles.csv → /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/cref/outputs

# %% [markdown]
# ## Step 3 — Full per-cluster statistics

# %%
FEATURE_COLS = ["area", "perimeter", "circularity", "aspect_ratio"]
STATS_COLS = FEATURE_COLS + ["max_intensity"]
N_TOTAL = len(meta)


def cluster_stats_block(sub, cluster_id):
    """Monospace summary text + flat dict for CSV."""
    n = len(sub)
    pct = 100.0 * n / N_TOTAL if N_TOTAL else 0.0
    n_images = sub["image"].nunique() if n else 0
    lines = [
        f"cluster={cluster_id}  n={n}  ({pct:.1f}% of all)  images={n_images}",
    ]
    row = {
        "cluster": cluster_id,
        "n": n,
        "pct_total": pct,
        "n_images": n_images,
    }
    if n == 0:
        lines.append("(empty cluster)")
        row["posterior_mean"] = np.nan
        row["posterior_min"] = np.nan
        for col in STATS_COLS:
            for stat in ("min", "mean", "max", "std"):
                row[f"{col}_{stat}"] = np.nan
        return "\n".join(lines), row
    for col in STATS_COLS:
        lines.append(
            f"{col:14s} min={sub[col].min():.3f}  mean={sub[col].mean():.3f}  "
            f"max={sub[col].max():.3f}  std={sub[col].std():.3f}"
        )
        row[f"{col}_min"] = float(sub[col].min())
        row[f"{col}_mean"] = float(sub[col].mean())
        row[f"{col}_max"] = float(sub[col].max())
        row[f"{col}_std"] = float(sub[col].std())
    row["posterior_mean"] = float(sub["posterior"].mean())
    row["posterior_min"] = float(sub["posterior"].min())
    lines.append(
        f"posterior:       min={sub['posterior'].min():.3f}  mean={sub['posterior'].mean():.3f}"
    )
    return "\n".join(lines), row


full_profile_rows = []
for c in range(K):
    sub = meta.loc[meta["cluster"] == c]
    _, row = cluster_stats_block(sub, c)
    full_profile_rows.append(row)

profiles_full_df = pd.DataFrame(full_profile_rows).set_index("cluster").sort_index()
profiles_full_df.to_csv(cfg.output_dir / "gmm_cluster_profiles_full.csv")
display(profiles_full_df.round(3))

# Per-image cluster counts
pivot = meta.pivot_table(index="image", columns="cluster", aggfunc="size", fill_value=0)
pivot.columns = [f"cluster_{c}" for c in pivot.columns]
pivot["total"] = pivot.sum(axis=1)
display(pivot)

# Feature histograms per cluster
fig, axes = plt.subplots(K, 4, figsize=(14, 3.2 * K), squeeze=False)
for c in range(K):
    sub = meta.loc[meta["cluster"] == c]
    for j, col in enumerate(FEATURE_COLS):
        ax = axes[c, j]
        if len(sub):
            ax.hist(sub[col], bins=40, color=colors_rgb[c], alpha=0.85, edgecolor="none")
        ax.set_title(f"cluster {c} — {col}", fontsize=9)
        ax.tick_params(labelsize=7)
plt.suptitle("Feature distributions by cluster", y=1.002)
plt.tight_layout()
plt.savefig(cfg.output_dir / "gmm_cluster_histograms.pdf", bbox_inches="tight")
plt.show()
print("Saved", cfg.output_dir / "gmm_cluster_profiles_full.csv")
# Out:
#              n  pct_total  n_images  area_min  area_mean  area_max  area_std  \
# cluster
# 0        38548     20.997       225      21.0     21.725      28.0     2.133
# 1        83449     45.455       225      20.0     77.192     193.5    27.923
# 2        48983     26.681       225      20.0     44.158      70.0     9.733
# 3        12607      6.867       225      20.0    746.552    9923.0  1234.546
#
#          perimeter_min  perimeter_mean  perimeter_max  ...  aspect_ratio_min  \
# cluster                                                ...
# 0               20.000          20.207         22.000  ...             0.500
# 1               18.828          38.756         72.971  ...             0.182
# 2               18.828          26.462         34.828  ...             0.600
# 3               20.485         142.009       3160.936  ...             0.010
#
#          aspect_ratio_mean  aspect_ratio_max  aspect_ratio_std  \
# cluster
# 0                    0.513             0.625             0.038
# 1                    0.776             1.778             0.205
# 2                    1.073             2.250             0.322
# 3                    1.083            75.400             1.303
#
#          max_intensity_min  max_intensity_mean  max_intensity_max  \
# cluster
# 0                      1.0               1.003                3.0
# 1                      1.0               2.820               31.0
# 2                      1.0               1.543                6.0
# 3                      1.0              10.513              101.0
#
#          max_intensity_std  posterior_mean  posterior_min
# cluster
# 0                    0.052           1.000          1.000
# 1                    1.171           0.991          0.498
# 2                    0.620           0.978          0.423
# 3                   11.990           0.984          0.501
#
# [4 rows x 25 columns]
#                                  cluster_0  cluster_1  cluster_2  cluster_3  \
# image
# CREF_P2-DOT_T1_A1_LBS255518.jpg        352        392        383         35
# CREF_P2-DOT_T1_A2_LBS255509.jpg        407        376        347         24
# CREF_P2-DOT_T1_A3_LBS255512.jpg        330        382        362         38
# CREF_P2-DOT_T1_A4_LBS255506.jpg        332        418        347         35
# CREF_P2-DOT_T1_A5_LBS255517.jpg        327        309        308         30
# ...                                    ...        ...        ...        ...
# CREF_PT-RIS_T3_C1_LBS263559.jpg        119        166        158         48
# CREF_PT-RIS_T3_C2_LBS263560.jpg        129        184        157         28
# CREF_PT-RIS_T3_C3_LBS263561.jpg        132        160        144         70
# CREF_PT-RIS_T3_C4_LBS263562.jpg        130        210        147         37
# CREF_PT-RIS_T3_C5_LBS263563.jpg        115        311        159         30
#
#                                  total
# image
# CREF_P2-DOT_T1_A1_LBS255518.jpg   1162
# CREF_P2-DOT_T1_A2_LBS255509.jpg   1154
# CREF_P2-DOT_T1_A3_LBS255512.jpg   1112
# CREF_P2-DOT_T1_A4_LBS255506.jpg   1132
# CREF_P2-DOT_T1_A5_LBS255517.jpg    974
# ...                                ...
# CREF_PT-RIS_T3_C1_LBS263559.jpg    491
# CREF_PT-RIS_T3_C2_LBS263560.jpg    498
# CREF_PT-RIS_T3_C3_LBS263561.jpg    506
# CREF_PT-RIS_T3_C4_LBS263562.jpg    524
# CREF_PT-RIS_T3_C5_LBS263563.jpg    615
#
# [225 rows x 5 columns]
# Saved /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/cref/outputs/gmm_cluster_profiles_full.csv

# %% [markdown]
# ## Step 4 — Patch extraction for montages

# %%
half = PATCH_SIZE // 2
roi_by_image = {reg["path"].name: reg["roi"] for reg in image_registry}

patches_raw = []
patch_valid = []
for _, row in meta.iterrows():
    roi = roi_by_image[row["image"]]
    H, W = roi.shape
    cy, cx = int(row["cy"]), int(row["cx"])
    y0, x0 = cy - half, cx - half
    if y0 < 0 or x0 < 0 or y0 + PATCH_SIZE > H or x0 + PATCH_SIZE > W:
        patches_raw.append(None)
        patch_valid.append(False)
        continue
    patch = roi[y0 : y0 + PATCH_SIZE, x0 : x0 + PATCH_SIZE].astype(np.float32)
    patches_raw.append(patch)
    patch_valid.append(True)

meta["patch_valid"] = patch_valid
valid_idx = np.where(meta["patch_valid"].to_numpy())[0]
patches_stack = np.stack([patches_raw[i] for i in valid_idx])
pmax = patches_stack.reshape(len(patches_stack), -1).max(axis=1)
pmax = np.clip(pmax, 1.0, None)
patches_norm = (patches_stack / pmax[:, None, None]).astype(np.float32)
valid_to_global = {j: valid_idx[j] for j in range(len(valid_idx))}
global_to_valid = {valid_idx[j]: j for j in range(len(valid_idx))}
STEP36_RAW_VMAX = max(25, int(np.ceil(float(patches_stack.max()))))
print(f"patches: {len(valid_idx)}/{len(meta)} valid ({PATCH_SIZE}×{PATCH_SIZE})")
# Out:
# patches: 179290/183587 valid (48×48)

# %% [markdown]
# ## Step 5 — Cluster evaluation plots

# %%
# 5.1 — Silhouette vs k (diagnostic; fit still uses cfg.n_clusters)
ks = range(2, 25)
sil = []
for k in ks:
    gm = GaussianMixture(n_components=k, covariance_type="full", random_state=cfg.random_state)
    gm.fit(X_scaled)
    pred = gm.predict(X_scaled)
    sil.append(silhouette_score(X_scaled, pred, sample_size=min(5000, len(X_scaled)), random_state=cfg.random_state))
plt.figure(figsize=(6, 3))
plt.plot(list(ks), sil, marker="o")
plt.xlabel("k")
plt.ylabel("silhouette")
plt.axvline(cfg.n_clusters, color="red", ls="--", label=f"cfg n_clusters={cfg.n_clusters}")
plt.title("Cluster-count selection (GMM on scaled features)")
plt.legend(fontsize=8)
plt.tight_layout()
plt.savefig(cfg.output_dir / "gmm_silhouette.pdf", bbox_inches="tight")
plt.show()
print("silhouette by k:", {k: round(s, 3) for k, s in zip(ks, sil)})
# Out:
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/mixture/_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# silhouette by k: {2: np.float64(0.569), 3: np.float64(0.33), 4: np.float64(0.222), 5: np.float64(0.184), 6: np.float64(0.239), 7: np.float64(0.239), 8: np.float64(0.282), 9: np.float64(0.282), 10: np.float64(0.284), 11: np.float64(0.249), 12: np.float64(0.255), 13: np.float64(0.255), 14: np.float64(0.264), 15: np.float64(0.229), 16: np.float64(0.23), 17: np.float64(0.278), 18: np.float64(0.257), 19: np.float64(0.256), 20: np.float64(0.274), 21: np.float64(0.278), 22: np.float64(0.302), 23: np.float64(0.263), 24: np.float64(0.284)}

# %%
# 5.2 — Extra feature-space scatters

# aspect_ratio = width of box ÷ height of box
# (both in pixels; width is horizontal extent, height is vertical.)
# How to read the aspect ratio:
# 1.0 About as wide as tall (square-ish blob)
# < 1.0 Taller than wide (vertical streak)
# > 1.0 Wider than tall (horizontal streak)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
scatter_kw = dict(c=labels, cmap=_cluster_cmap, norm=_cluster_norm, alpha=0.65, s=6)
axes[0].scatter(X[:, 0], X[:, 3], **scatter_kw)
axes[0].set_xlabel("area (px)")
axes[0].set_ylabel("aspect ratio")
axes[0].set_title("Area vs aspect ratio")
axes[0].grid(True, alpha=0.3)
axes[1].scatter(X[:, 2], X[:, 3], **scatter_kw)
axes[1].set_xlabel("circularity")
axes[1].set_ylabel("aspect ratio")
axes[1].set_title("Circularity vs aspect ratio")
axes[1].grid(True, alpha=0.3)
legend_handles = [
    Patch(
        facecolor=colors_rgb[c],
        edgecolor="white",
        label=f"cluster {c} (n={int((labels == c).sum())})",
    )
    for c in range(K)
]
fig.legend(
    handles=legend_handles,
    loc="upper center",
    
    bbox_to_anchor=(0.5, 1.06),
    ncol=K,
    fontsize=9,
    framealpha=0.9,
)
plt.tight_layout()
plt.savefig(cfg.output_dir / "gmm_feature_scatters.png", bbox_inches="tight")
plt.show()

# %%
# 5.3 — Per-cluster montages (normalized top / raw bottom)

# Posterior is the GMM’s assignment confidence: for each track, 
# the probability that it belongs to the cluster it was assigned to.
# Value	Interpretation
# ≈ 1.0 | Strong, unambiguous assignment
# ≈ 0.5 | Ambiguous — other clusters are similarly likely
# Low min in a cluster | Some members are borderline

def cluster_montage(c, n=MONTAGE_N):
    idx_all = np.where(meta["cluster"].to_numpy() == c)[0]
    idx = idx_all[meta.iloc[idx_all]["patch_valid"].to_numpy()]
    sub = meta.iloc[idx_all]
    stats_txt, stats_row = cluster_stats_block(sub, c)
    if len(idx) == 0:
        print(f"cluster {c}: no valid patches for montage")
        return stats_row
    pick = np.random.choice(idx, min(n, len(idx)), replace=False)
    cols = MONTAGE_COLS
    rows = int(np.ceil(len(pick) / cols))
    fig_h = 2 * rows * 1.25 + 2.0
    fig, axes = plt.subplots(2 * rows, cols, figsize=(cols * 1.35, fig_h))
    axes = np.atleast_2d(axes)
    for ax in np.ravel(axes):
        ax.axis("off")
    for j, gi in enumerate(pick):
        vi = global_to_valid[gi]
        r, col = divmod(j, cols)
        axes[r, col].imshow(patches_norm[vi], cmap="gray", vmin=0, vmax=1)
        axes[rows + r, col].imshow(patches_stack[vi], cmap="gray", vmin=0, vmax=STEP36_RAW_VMAX)
    fig.suptitle(
        f"cluster {c} — normalized (top) vs raw 0–{STEP36_RAW_VMAX} (bottom)",
        fontsize=11,
        y=0.995,
    )
    fig.text(0.02, 0.98, stats_txt, fontsize=7.2, va="top", family="monospace", transform=fig.transFigure)
    plt.subplots_adjust(top=0.78, hspace=0.12, wspace=0.05)
    out = cfg.output_dir / f"cluster_{c}.png"
    fig.savefig(out, dpi=110, bbox_inches="tight")
    plt.show()
    return stats_row

for c in range(K):
    cluster_montage(c)
print("Saved cluster_*.png")
# Out:
# Saved cluster_*.png

# %%
# 5.4 — Mean patch per cluster
fig, axes = plt.subplots(2, K, figsize=(2.0 * K, 4.2))
if K == 1:
    axes = np.array(axes).reshape(2, 1)
for c in range(K):
    idx_all = np.where(meta["cluster"].to_numpy() == c)[0]
    idx = idx_all[meta.iloc[idx_all]["patch_valid"].to_numpy()]
    axes[0, c].set_title(f"c{c}", fontsize=9)
    axes[1, c].axis("off")
    axes[0, c].axis("off")
    if len(idx) == 0:
        axes[0, c].text(0.5, 0.5, "empty", ha="center", va="center")
        axes[1, c].text(0.5, 0.5, "empty", ha="center", va="center")
        continue
    vi = [global_to_valid[gi] for gi in idx]
    norm_mean = patches_norm[vi].mean(axis=0)
    raw_mean = patches_stack[vi].mean(axis=0)
    axes[0, c].imshow(norm_mean, cmap="gray", vmin=0, vmax=1)
    axes[1, c].imshow(raw_mean, cmap="gray", vmin=0, vmax=STEP36_RAW_VMAX)
axes[0, 0].set_ylabel("norm mean", fontsize=9)
axes[1, 0].set_ylabel(f"raw mean\n0–{STEP36_RAW_VMAX}", fontsize=9)
fig.suptitle("Mean patch per cluster")
plt.tight_layout()
fig.savefig(cfg.output_dir / "gmm_cluster_mean_patches.png", dpi=110, bbox_inches="tight")
plt.show()

# %%
# 5.5 — t-SNE of scaled feature space

# Each dot is one detected track (blob). 
# Its position is not (area, circularity) directly — it’s a 2D embedding 
# built from the 4 scaled GMM features:
# area
# perimeter
# circularity
# aspect ratio

sub_n = min(4000, len(X_scaled))
sidx = np.random.choice(len(X_scaled), sub_n, replace=False)
Zp = PCA(n_components=min(4, X_scaled.shape[1]), random_state=cfg.random_state).fit_transform(X_scaled[sidx])
emb2d = TSNE(n_components=2, perplexity=30, init="pca", random_state=cfg.random_state).fit_transform(Zp)
plt.figure(figsize=(7, 6))
sc = plt.scatter(
    emb2d[:, 0],
    emb2d[:, 1],
    c=meta["cluster"].to_numpy()[sidx],
    cmap=_cluster_cmap,
    norm=_cluster_norm,
    s=6,
    alpha=0.75,
)
legend_handles = [
    Patch(facecolor=colors_rgb[c], edgecolor="white", label=f"cluster {c}")
    for c in range(K)
]
plt.legend(handles=legend_handles, loc="best", fontsize=8)
plt.title("t-SNE of GMM feature space (scaled geometry)")
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig(cfg.output_dir / "gmm_tsne.pdf", dpi=120, bbox_inches="tight")
plt.show()
# Out:
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: divide by zero encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: overflow encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: invalid value encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: overflow encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: divide by zero encountered in matmul
#   B = Q.T @ M
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: overflow encountered in matmul
#   B = Q.T @ M
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: invalid value encountered in matmul
#   B = Q.T @ M
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: divide by zero encountered in matmul
#   U = Q @ Uhat
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: overflow encountered in matmul
#   U = Q @ Uhat
# /Users/fc/miniforge3/envs/pytmetalbeta/lib/python3.13/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: invalid value encountered in matmul
#   U = Q @ Uhat

# %%
# 5.6 — Dense ROI window with all clusters visible

def _pick_roi_all_clusters(meta_df, size, grid, n_clusters):
    best = (-1, -1, None, None, None, None)
    roi_lookup = {reg["path"].name: reg["roi"] for reg in image_registry}
    for img_name, grp in meta_df.groupby("image"):
        roi = roi_lookup[img_name]
        H, W = roi.shape
        if H < size or W < size:
            continue
        ys = np.arange(0, H - size, grid)
        xs = np.arange(0, W - size, grid)
        for y0 in ys:
            for x0 in xs:
                mask = (
                    (grp["cx"] >= x0)
                    & (grp["cx"] < x0 + size)
                    & (grp["cy"] >= y0)
                    & (grp["cy"] < y0 + size)
                )
                sub = grp.loc[mask]
                if sub.empty:
                    continue
                n_cl = sub["cluster"].nunique()
                n_cand = len(sub)
                key = (n_cl, n_cand)
                if key > best[:2]:
                    best = (n_cl, n_cand, img_name, int(x0), int(y0), sub)
    return best


def _plot_roi_cluster_window(img_name, x0, y0, size, save_path):
    """Stretch ROI + cluster markers for a fixed window (cross-run comparable)."""
    roi_lookup = {reg["path"].name: reg["roi"] for reg in image_registry}
    if img_name not in roi_lookup:
        print(f"Skip ROI plot: {img_name} not in image_registry")
        return
    roi = roi_lookup[img_name]
    H, W = roi.shape
    if x0 < 0 or y0 < 0 or x0 + size > W or y0 + size > H:
        raise ValueError(
            f"ROI window ({x0},{y0})+{size} out of bounds for {img_name} ({W}×{H})"
        )
    cands = meta.loc[
        (meta["image"] == img_name)
        & (meta["cx"] >= x0)
        & (meta["cx"] < x0 + size)
        & (meta["cy"] >= y0)
        & (meta["cy"] < y0 + size)
    ]
    crop = roi[y0 : y0 + size, x0 : x0 + size]
    stretch = np.clip(crop.astype(int) * 8, 0, 255)
    clusters_present = sorted(cands["cluster"].unique()) if len(cands) else []
    n_cl = len(clusters_present)
    n_cand = len(cands)
    missing = [c for c in range(K) if c not in clusters_present]
    status = "all clusters present" if not missing else f"missing clusters {missing}"

    fig, ax = plt.subplots(1, 2, figsize=(14, 7))
    ax[0].imshow(stretch, cmap="gray")
    ax[0].set_title(f"ROI stretch 8× ({img_name})")
    ax[0].axis("off")
    ax[1].imshow(stretch, cmap="gray")
    for _, r in cands.iterrows():
        ax[1].scatter(
            r["cx"] - x0,
            r["cy"] - y0,
            s=18,
            c=[colors_rgb[int(r["cluster"])]],
            edgecolors="white",
            linewidths=0.3,
        )
    ax[1].set_title(f"Cluster markers ({n_cl}/{K} clusters, {n_cand} events)")
    ax[1].axis("off")
    fig.suptitle(f"{img_name} @ ({x0},{y0}) {size}×{size} — {status}", y=1.01)
    plt.tight_layout()
    fig.savefig(save_path, dpi=120, bbox_inches="tight")
    plt.show()
    print(f"ROI: {img_name}  x0={x0}  y0={y0}  clusters={clusters_present}  n={n_cand}")


best = _pick_roi_all_clusters(meta, ROI_WINDOW, 200, K)
n_cl, n_cand, img_name, x0, y0, _cands = best
if img_name is None:
    raise RuntimeError("No ROI window found for cluster overlay plot")
_plot_roi_cluster_window(
    img_name,
    x0,
    y0,
    ROI_WINDOW,
    cfg.output_dir / "gmm_all_clusters_roi.png",
)

# 5.6b — fixed comparison window (same geometry across runs)
_plot_roi_cluster_window(
    COMPARE_ROI_IMAGE,
    COMPARE_ROI_X0,
    COMPARE_ROI_Y0,
    ROI_WINDOW,
    cfg.output_dir / "gmm_compare_roi_LBS255612.png",
)
# Out:
# ROI: CREF_PT-RIS_T2_B5_LBS259566.jpg  x0=0  y0=800  clusters=[np.int64(0), np.int64(1), np.int64(2), np.int64(3)]  n=74
# ROI: CREF_P2-DOT_T1_A1_LBS255518.jpg  x0=200  y0=400  clusters=[np.int64(0), np.int64(1), np.int64(2), np.int64(3)]  n=26

# %%
# 5.7 — Per-cluster spatial panels on sample image
if image_registry:
    sample = image_registry[0]
    start = sample["label_start"]
    end = start + sample["counts"]
    sample_labels = labels[start:end]
    roi_norm = cv2.normalize(sample["roi"], None, 0, 255, cv2.NORM_MINMAX)
    fig, axes = plt.subplots(1, K, figsize=(5 * K, 5))
    if K == 1:
        axes = [axes]
    for c in range(K):
        roi_color = cv2.cvtColor(roi_norm, cv2.COLOR_GRAY2BGR)
        for idx, cnt in enumerate(sample["contours"]):
            if sample_labels[idx] != c:
                continue
            cv2.drawContours(roi_color, [cnt], -1, colors_bgr[c], 1)
        n_c = int((sample_labels == c).sum())
        axes[c].imshow(cv2.cvtColor(roi_color, cv2.COLOR_BGR2RGB))
        axes[c].set_title(f"cluster {c}  (n={n_c})")
        axes[c].axis("off")
    fig.suptitle(f"Per-cluster contours — {sample['path'].name}")
    plt.tight_layout()
    plt.savefig(cfg.output_dir / "gmm_per_cluster_spatial.pdf", bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## Step 6 — Watershed split, saliency artifacts, count comparison
#
# Two-pass flow: **GMM baseline** → watershed on large blobs in selected clusters → **saliency** artifact tagging (`area × max_intensity`) → per-image counts vs ImageJ `Summary.csv`.
#
# Edit `WATERSHED_CLUSTERS`, `WS_METHOD`, and `ARTIFACT_CLUSTERS` in Step 0 after inspecting outputs below.

# %%
# 6.1 — Cluster profiles (mean area + saliency) to pick watershed clusters
meta_gmm = meta_gmm.copy()
meta_gmm["saliency"] = meta_gmm["area"] * meta_gmm["max_intensity"]
prof_gmm = meta_gmm.groupby("cluster").agg(
    n=("area", "size"),
    area=("area", "mean"),
    max_int=("max_intensity", "mean"),
    saliency=("saliency", "mean"),
)
display(prof_gmm.round(3))

ws_clusters = resolve_ws_clusters(
    meta_gmm, meta_gmm["cluster"].to_numpy(), cfg, WATERSHED_CLUSTERS or None
)
if WS_CLUSTER_FILTER:
    print(f"Watershed clusters (area >= {WS_MIN_AREA} px): {ws_clusters}")
else:
    print(f"Watershed: area-only mode (>= {WS_MIN_AREA} px), all clusters")
    ws_clusters = []

cfg.ws_min_area = WS_MIN_AREA
cfg.ws_min_fragment_area = WS_MIN_FRAGMENT_AREA
cfg.ws_cluster_filter = WS_CLUSTER_FILTER
cfg.ws_method = WS_METHOD
# Out:
#              n     area  max_int   saliency
# cluster
# 0        38548   21.725    1.003     21.779
# 1        83449   77.192    2.820    238.366
# 2        48983   44.158    1.543     69.186
# 3        12607  746.552   10.513  14457.200
# Watershed: area-only mode (>= 160 px), all clusters

# %%
# 6.2 — Watershed method comparison (diagnostic on first image)
diag_reg = image_registry[0]
diag_labels = meta_gmm.loc[
    meta_gmm["image"] == diag_reg["path"].name, "cluster"
].to_numpy()
method_cmp = compare_watershed_methods(
    diag_reg["roi"], diag_reg["contours"], diag_labels, cfg, ws_clusters
)
method_df = pd.DataFrame(method_cmp).T
display(method_df)
print(f"Diagnostic image: {diag_reg['path'].name}  |  production WS_METHOD = {WS_METHOD}")
# Out:
#                 n_candidates  n_split_parents  n_total_fragments  error
# distance_peaks          32.0             19.0               61.0    NaN
# h_minima                32.0              0.0               32.0    NaN
# cv2_marker              32.0             12.0               46.0    NaN
# Diagnostic image: CREF_P2-DOT_T1_A1_LBS255518.jpg  |  production WS_METHOD = distance_peaks

# %%
# 6.3 — Apply watershed pass (re-predict clusters, no GMM re-fit)
meta_ws, X_ws, labels_ws, ws_stats = apply_watershed_pass(
    image_registry,
    meta_gmm,
    meta_gmm["cluster"].to_numpy(),
    gmm,
    scaler,
    cfg,
    ws_clusters,
)
meta_ws = meta_ws.copy()
meta_ws["cluster"] = labels_ws
print(ws_stats)
# Out:
# {'ws_clusters': [], 'n_parents_split': 6865, 'n_new_fragments': 38115, 'n_before': 183587, 'n_after': 214837}

# %%
# 6.4 — Saliency artifact tagging (override ARTIFACT_CLUSTERS in Step 0)
meta_ws["saliency"] = meta_ws["area"] * meta_ws["max_intensity"]
prof_ws, suggested = suggest_artifact_clusters(meta_ws, cfg.artifact_saliency_ratio)
display(prof_ws.round(3))

artifact_clusters = ARTIFACT_CLUSTERS if ARTIFACT_CLUSTERS is not None else suggested
ARTIFACT_CLUSTERS = [0]  # manual override
meta_ws["is_track"] = ~meta_ws["cluster"].isin(artifact_clusters)
print("Using ARTIFACT_CLUSTERS =", artifact_clusters, "(override manually in Step 0)")
prof_ws.to_csv(cfg.output_dir / "gmm_cluster_saliency_profiles.csv")
# Out:
#               n     area  max_int  saliency  suggest_artifact
# cluster
# 0         38774   21.725    1.004    21.819              True
# 1        100169   78.575    3.128   245.773             False
# 2         53154   43.837    1.580    69.274              True
# 3         22740  318.587   11.159  3554.977             False
# Using ARTIFACT_CLUSTERS = [0] (override manually in Step 0)

# %%
# 6.5 — Count comparison vs ImageJ Summary.csv
macro_map = load_macro_counts(cfg.macro_summary)
final_df = build_count_comparison(macro_map, meta_gmm, meta_ws, artifact_clusters)
final_df.to_csv(cfg.output_dir / "gmm_count_comparison.csv", index=False)
display(final_df)
print(
    "TOTALS:",
    final_df[["imagej_count", "gmm_count", "gmm_ws_count", "gmm_ws_clean_count"]].sum().astype(int).to_dict(),
)
save_count_comparison_plots(final_df, cfg.output_dir)

x = np.arange(len(final_df))
w = 0.2
fig, ax = plt.subplots(figsize=(14, 5))
ax.bar(x - 1.5 * w, final_df["imagej_count"], w, label="ImageJ macro")
ax.bar(x - 0.5 * w, final_df["gmm_count"], w, label="GMM")
ax.bar(x + 0.5 * w, final_df["gmm_ws_count"], w, label="GMM + WS")
ax.bar(x + 1.5 * w, final_df["gmm_ws_clean_count"], w, label="GMM + WS − artifacts")
ax.set_xticks(x)
ax.set_xticklabels([image_display_name(n) for n in final_df["image"]], rotation=90)
ax.set_ylabel("count")
ax.legend()
ax.set_title("Per-image count comparison")
plt.tight_layout()
plt.savefig(cfg.output_dir / "gmm_count_comparison.png", dpi=120, bbox_inches="tight")
plt.show()

_count_cols = {
    "imagej_count": "ImageJ macro",
    "gmm_count": "GMM",
    "gmm_ws_count": "GMM + WS",
    "gmm_ws_clean_count": "GMM + WS − artifacts",
}
_totals = final_df[list(_count_cols)].sum().astype(int)
print("Total events (sum over all images):")
for col, label in _count_cols.items():
    print(f"  {label}: {_totals[col]}")

print("Saved", cfg.output_dir / "gmm_count_comparison.csv")
# Out:
#                                image  imagej_count  gmm_count  gmm_ws_count  \
# 0    CREF_P2-DOT_T1_A1_LBS255518.jpg          1042       1162          1191
# 1    CREF_P2-DOT_T1_A2_LBS255509.jpg          1070       1154          1172
# 2    CREF_P2-DOT_T1_A3_LBS255512.jpg           988       1112          1161
# 3    CREF_P2-DOT_T1_A4_LBS255506.jpg          1018       1132          1185
# 4    CREF_P2-DOT_T1_A5_LBS255517.jpg           894        974          1001
# ..                               ...           ...        ...           ...
# 220  CREF_PT-RIS_T3_C1_LBS263559.jpg           398        491           658
# 221  CREF_PT-RIS_T3_C2_LBS263560.jpg           442        498           526
# 222  CREF_PT-RIS_T3_C3_LBS263561.jpg           410        506           674
# 223  CREF_PT-RIS_T3_C4_LBS263562.jpg           465        524           642
# 224  CREF_PT-RIS_T3_C5_LBS263563.jpg           516        615           663
#
#      gmm_ws_clean_count
# 0                   839
# 1                   765
# 2                   831
# 3                   853
# 4                   674
# ..                  ...
# 220                 538
# 221                 397
# 222                 539
# 223                 510
# 224                 548
#
# [225 rows x 5 columns]
# TOTALS: {'imagej_count': 154740, 'gmm_count': 183587, 'gmm_ws_count': 214837, 'gmm_ws_clean_count': 176063}
# Total events (sum over all images):
#   ImageJ macro: 154740
#   GMM: 183587
#   GMM + WS: 214837
#   GMM + WS − artifacts: 176063
# Saved /Users/fc/Library/CloudStorage/OneDrive-MuseoStoricodellaFisicaeCentroStudieRicercheEnricoFermi/acme/CREF/sourceforge/github/radon/cref/outputs/gmm_count_comparison.csv

# %%
# 6.7 — Visual ROI comparison: GMM / GMM+WS / GMM+WS clean
roi_lookup = {reg["path"].name: reg["roi"] for reg in image_registry}
roi_vis = roi_lookup[VISUAL_COMPARE_ROI_IMAGE]
_vis_stem = Path(VISUAL_COMPARE_ROI_IMAGE).stem
counts_vis, fig_vis = plot_roi_three_variants(
    roi_vis,
    meta_gmm,
    meta_ws,
    VISUAL_COMPARE_ROI_IMAGE,
    VISUAL_COMPARE_ROI_X0,
    VISUAL_COMPARE_ROI_Y0,
    VISUAL_COMPARE_ROI_SIZE,
    colors_rgb,
    save_path=cfg.output_dir / f"gmm_roi_compare_{_vis_stem}.png",
)
plt.show()
print(
    f"in ROI ({VISUAL_COMPARE_ROI_X0},{VISUAL_COMPARE_ROI_Y0},{VISUAL_COMPARE_ROI_SIZE}):",
    counts_vis,
)
# Out:
# in ROI (700,1400,700): {'GMM': 20, 'GMM + WS': 20, 'GMM + WS clean': 15}
